# %% [markdown]
# # Demo notebook
# Markdown cells are not Python and must be ignored.

# %%
# !pip install requests
import pickle

# %%
def run_user_expression(expr):
    return eval(expr)

# %%
# %%bash
# echo 'not python at all' $(rm -rf /)

# %%
AWS_SECRET_ACCESS_KEY = "wJalrXUtnFEMI1K7MDENGbPxRfiCYEXAMPLEKEY"
